# %% [markdown]
# # Landscape classification, Convolutionnal Neural Network
#
# To get a better model, the CNN seems to be the best way to improve the accuracy

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import skimage as sk
import scipy as sp
import cv2 as cv
import os
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
# Loading the images, 
# they are named 1.jpg, 2.jpg, 3.jpg ... so my goal is to automatically get the number of every image so that
# we can add images in the file.

images = os.listdir("./input")

images = [os.path.splitext(images_num)[0] for images_num in images]
images.sort()
images.pop(0)

images = np.array(images, dtype = int)
images.sort()

images
# Out:
# array([   2,    3,    4, ..., 2685, 2686, 2687])

# %%
data_set = np.zeros((len(images),256,256,3))
data_set.shape

# This loop is a little bit long but I did not find a better way to do it.

for i in range(len(images)) :
    data_set[i-1,:,:,:] = sk.io.imread("./input/"+str(images[i-1])+".jpg") / 255
    
print("Shape of the entry images (number, height, width, channels): ", data_set.shape)
# Out:
# Shape of the entry images (number, height, width, channels):  (2686, 256, 256, 3)

# %%
# This portion of the code is here to label the data because the images were sorted by class but not labeled

class_names = ["ocean & sea", "forest", "road", "building", "mountains"] # 0 : ocean & sea, 1 : forest, 2 : road ...


# I also separated the images into training and test sets. 
# First, I defined the size of every vector I am going to use.

label_set = np.zeros(len(images))

data_train = np.zeros((1352,256,256,3))
label_train = np.zeros(1352)


data_test = np.zeros((281,256,256,3))
label_test = np.zeros(281)

# Then, I matched every image with its label.

data_train[0:300,:,:,:] = data_set[:300,:,:,:]
label_train[0:300] = 0
label_train[140] = 1


data_test[0:58,:,:,:] = data_set[300:358,:,:,:]
label_test[0:58] = 0


data_train[300:541,:,:,:] = data_set[359:600,:,:,:]
data_test[58:143,:,:,:] = data_set[601:686,:,:,:]
label_train[300:541] = 1
label_test[58:143] = 1


data_train[541:754,:,:,:] = data_set[687:900,:,:,:]
data_test[143:188,:,:,:] = data_set[901:946,:,:,:]
label_train[541:754] = 2
label_test[143:188] = 2


data_train[754:1007,:,:,:] = data_set[947:1200,:,:,:]
data_test[188:241,:,:,:] = data_set[1201:1254,:,:,:]
label_train[754:1007] = 3
label_test[188:241] = 3


data_train[1007:1352,:,:,:] = data_set[1255:1600,:,:,:]
data_test[241:281,:,:,:] = data_set[1601:1641,:,:,:]
label_train[1007:1352] = 4
label_test[241:281] = 4

# Then I check if there is no issue with the indices of the images in the data set and the train set. Such issues 
# would manifest as a black image, so I check the maximum pixel value to determine if its value is greater than zero.

label_test = label_test.astype(int)
label_train = label_train.astype(int)

# %%
# Then I check if there is no issue with the indices of the images in the data set and the train set. Such issues 
# would manifest as a black image, so I check the maximum pixel value to determine if its value is greater than zero.

for i in range(len(data_train)):
    if np.max(data_train[i,:,:,:]) == 0 :
       print(i)

for i in range(len(data_test)):
    if np.max(data_test[i,:,:,:]) == 0 :
       print(i)

# %%
# Here is an insight of the images

plt.figure(figsize = (12,12))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(data_train[20*i,:,:,:])
    plt.xticks([])
    plt.yticks([])
    plt.xlabel(class_names[label_train[20*i]])

# %%
# So here is the model, it has many layers because  It is a common practice to double the number of filters after 
# each pooling layer. since a pooling layer divides each spatial dimension by a factor of 2, 
# we can afford to double the number of feature maps in the next layer without fear of exploding
# the number of parameters, memory usage, or computational load.
# We also add two dropout layers, with a dropout rate of 50% each, to reduce overfitting.
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, 3, activation="relu", padding="same", input_shape=[256, 256, 3]),
    tf.keras.layers.MaxPooling2D(2),
    tf.keras.layers.Conv2D(128, 3, activation="relu", padding="same"),
    tf.keras.layers.Conv2D(128, 3, activation="relu", padding="same"),
    tf.keras.layers.MaxPooling2D(2),
    tf.keras.layers.Conv2D(256, 3, activation="relu", padding="same"),
    tf.keras.layers.Conv2D(256, 3, activation="relu", padding="same"),
    tf.keras.layers.MaxPooling2D(2),
    tf.keras.layers.Conv2D(512, 3, activation="relu", padding="same"),
    tf.keras.layers.Conv2D(512, 3, activation="relu", padding="same"),
    tf.keras.layers.MaxPooling2D(2),
    tf.keras.layers.Conv2D(1024, 3, activation="relu", padding="same"),
    tf.keras.layers.Conv2D(1024, 3, activation="relu", padding="same"),
    tf.keras.layers.MaxPooling2D(2),
    tf.keras.layers.Conv2D(2048, 3, activation="relu", padding="same"),
    tf.keras.layers.Conv2D(2048, 3, activation="relu", padding="same"),
    tf.keras.layers.MaxPooling2D(2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(5)
])
# Out:
# 2024-02-05 12:02:03.099814: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2024-02-05 12:02:03.099840: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-02-05 12:02:03.099849: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-02-05 12:02:03.100090: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-05 12:02:03.100105: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# '\ntf.keras.layers.Conv2D(512, 3, activation="relu", padding="same"),\n    tf.keras.layers.Conv2D(512, 3, activation="relu", padding="same"),\n    tf.keras.layers.MaxPooling2D(2),\n    tf.keras.layers.Conv2D(1024, 3, activation="relu", padding="same"),\n    tf.keras.layers.Conv2D(1024, 3, activation="relu", padding="same"),\n    tf.keras.layers.MaxPooling2D(2),\n'

# %%
model.compile(optimizer = 'sgd',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'])

# %%
hist = model.fit(data_train, label_train, epochs=60,
                validation_data = (data_test, label_test))
# Out:
# Epoch 1/60
# 2024-02-05 12:02:07.635470: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 43/43 [==============================] - ETA: 0s - loss: 1.6058 - accuracy: 0.2263
# 2024-02-05 12:02:55.519381: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 43/43 [==============================] - 51s 1s/step - loss: 1.6058 - accuracy: 0.2263 - val_loss: 1.6165 - val_accuracy: 0.1423
# Epoch 2/60
# 43/43 [==============================] - 49s 1s/step - loss: 1.6001 - accuracy: 0.2626 - val_loss: 1.6204 - val_accuracy: 0.1423
# Epoch 3/60
# 43/43 [==============================] - 49s 1s/step - loss: 1.5956 - accuracy: 0.2626 - val_loss: 1.6263 - val_accuracy: 0.1423
# Epoch 4/60
# 43/43 [==============================] - 49s 1s/step - loss: 1.5919 - accuracy: 0.2522 - val_loss: 1.6273 - val_accuracy: 0.1423
# Epoch 5/60
# 43/43 [==============================] - 49s 1s/step - loss: 1.5941 - accuracy: 0.2515 - val_loss: 1.6329 - val_accuracy: 0.1423
# Epoch 6/60
# 43/43 [==============================] - 49s 1s/step - loss: 1.5942 - accuracy: 0.2515 - val_loss: 1.6294 - val_accuracy: 0.1423
# Epoch 7/60
# 43/43 [==============================] - 49s 1s/step - loss: 1.5931 - accuracy: 0.2507 - val_loss: 1.6298 - val_accuracy: 0.1423
# Epoch 8/60
# 43/43 [==============================] - 53s 1s/step - loss: 1.5906 - accuracy: 0.2522 - val_loss: 1.6274 - val_accuracy: 0.1423
# Epoch 9/60
# 43/43 [==============================] - 53s 1s/step - loss: 1.5891 - accuracy: 0.2522 - val_loss: 1.6296 - val_accuracy: 0.1423
# Epoch 50/60
# 43/43 [==============================] - 52s 1s/step - loss: 0.7860 - accuracy: 0.7234 - val_loss: 1.0920 - val_accuracy: 0.6370
# Epoch 51/60
# 43/43 [==============================] - 49s 1s/step - loss: 0.8312 - accuracy: 0.7093 - val_loss: 1.2990 - val_accuracy: 0.5765
# Epoch 52/60
# 43/43 [==============================] - 49s 1s/step - loss: 0.8073 - accuracy: 0.7167 - val_loss: 1.1588 - val_accuracy: 0.6299
# Epoch 53/60
# 43/43 [==============================] - 49s 1s/step - loss: 0.7733 - accuracy: 0.7145 - val_loss: 0.9509 - val_accuracy: 0.6762
# Epoch 54/60
# 43/43 [==============================] - 49s 1s/step - loss: 0.7580 - accuracy: 0.7322 - val_loss: 1.0803 - val_accuracy: 0.6584
# Epoch 55/60
# 43/43 [==============================] - 50s 1s/step - loss: 0.7570 - accuracy: 0.7374 - val_loss: 1.1434 - val_accuracy: 0.5943
# Epoch 56/60
# 43/43 [==============================] - 49s 1s/step - loss: 0.6984 - accuracy: 0.7493 - val_loss: 1.6522 - val_accuracy: 0.5267
# Epoch 57/60
# 43/43 [==============================] - 49s 1s/step - loss: 0.7848 - accuracy: 0.7322 - val_loss: 1.1250 - val_accuracy: 0.6299
# Epoch 58/60
# 43/43 [==============================] - 49s 1s/step - loss: 0.7411 - accuracy: 0.7515 - val_loss: 1.1786 - val_accuracy: 0.6548
# Epoch 59/60
# 43/43 [==============================] - 49s 1s/step - loss: 0.7211 - accuracy: 0.7485 - val_loss: 1.2612 - val_accuracy: 0.5445
# Epoch 60/60
# 43/43 [==============================] - 49s 1s/step - loss: 0.7020 - accuracy: 0.7448 - val_loss: 1.3553 - val_accuracy: 0.5907

# %%
pd.DataFrame(hist.history).plot(figsize=(8, 5)) 
plt.grid(True)
plt.gca().set_ylim(0, 1) 
plt.xlabel("Epoch n°" )
plt.show()

# %% [markdown]
# # Conclusion
#
# The model appears to improve as the accuracy increases, but around epoch 45, it begins to overfit the data, resulting in less consistent accuracy. Another issue could be the size of the dataset as I have only around 1600 images and 5 classes.
# I am currently trying to modify the hyperparameters to find the best values for the model.

# %%
prob_model = tf.keras.Sequential([
    model,
    tf.keras.layers.Softmax()])

# %%
predictions = prob_model.predict(data_test)
# Out:
# 1/9 [==>...........................] - ETA: 1s
# 2024-02-05 12:55:28.401863: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 9/9 [==============================] - 2s 277ms/step

# %%
def plot_image(i, predictions_array, true_label, img):
    true_label, img = true_label[i], img[i]
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img, cmap=plt.cm.binary)
    
    predicted_label = np.argmax(predictions_array)
    
    if predicted_label == true_label:
        color = 'green'
    else:
        color = 'red'
    
    plt.xlabel("  {} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)
def plot_value_array(i, predictions_array, true_label):
    true_label = true_label[i]
    plt.xticks(range(5))
    plt.yticks([])
    thisplot = plt.bar(range(5), predictions_array, color="#777777")
    
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('green')

# %%
plt.figure(figsize=(13,10))
for i in range(0,250, 25):
    plt.subplot(5,4,2*int(i/25)+1)
    plot_image(i, predictions[i], label_test, data_test)
    plt.subplot(5,4,2*int(i/25)+2)
    plot_value_array(i, predictions[i],  label_test)
plt.show()
